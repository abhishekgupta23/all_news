# %%
# !pip install pillow
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\abhishek narayan\desktop\web app\streamlit\scripts\python.exe -m pip install --upgrade pip' command.

# %%
from PIL import Image

# %%
img = Image.open("background.png")

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600 at 0x1B8CD4EC4F0>

# %%
img.format
# Out:
# 'PNG'

# %%
img.convert('1')
# Out:
# <PIL.Image.Image image mode=1 size=800x600 at 0x1B8CDBF0E80>

# %%
img.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=800x600 at 0x1B8CE31BBE0>

# %%
img.size
# Out:
# (800, 600)
